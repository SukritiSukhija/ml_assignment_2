# %%
import sys
import os

import pandas as pd


# Add parent directory to path
sys.path.append(os.path.abspath(".."))

# %%
from utils import load_and_preprocess, evaluate_model

# %%
from models import get_models

# %%
X_train, X_test, y_train, y_test = load_and_preprocess("../data/adult.data")

# Get models
models = get_models()

results = {}

for name, model in models.items():
    print(f"Training {name}...")
    results[name] = evaluate_model(model, X_train, X_test, y_train, y_test)

# Create comparison table
comparison_df = pd.DataFrame(results).T
comparison_df
# Out:
# C:\Users\Sukriti Sukhija\Documents\ml_assignment_2\utils.py:32: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["income"] = df["income"].replace({
# Training Logistic Regression...
# Training Decision Tree...
# Training KNN...
# Training Naive Bayes...
# Training Random Forest...
# Training XGBoost...
#                      Accuracy       AUC  Precision    Recall        F1  \
# Logistic Regression  0.811915  0.908959   0.573637  0.852041  0.685656
# Decision Tree        0.857823  0.907169   0.720770  0.668367  0.693580
# KNN                  0.825580  0.845398   0.653191  0.587372  0.618536
# Naive Bayes          0.420697  0.683263   0.290200  0.972577  0.447017
# Random Forest        0.864271  0.920341   0.795848  0.586735  0.675477
# ...

# %%
import joblib
import os

os.makedirs("../saved_models", exist_ok=True)

for name, model in models.items():
    model.fit(X_train, y_train)
    filename = name.replace(" ", "_") + ".pkl"
    joblib.dump(model, f"../saved_models/{filename}")

print("All models saved successfully.")
# Out:
# All models saved successfully.

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pd.DataFrame(X_test).to_csv("../test_processed.csv", index=False)

# %%
comparison_df.to_csv("../saved_models/model_metrics.csv")

# %%
import pandas as pd

# Convert scaled array back to DataFrame
test_df = pd.DataFrame(X_test)
test_df["income"] = y_test.values

test_df.to_csv("../test_with_labels.csv", index=False)

print("Test file with labels saved.")
# Out:
# Test file with labels saved.
